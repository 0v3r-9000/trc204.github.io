# %% [markdown]
# <a href="https://colab.research.google.com/github/0v3r-9000/trc204.github.io/blob/main/DecisionTreeHeartAttackPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Set larger figure size for better readability
plt.figure(figsize=(20, 10))

# Plot the tree with controlled depth and readable labels
tree.plot_tree(
    dtree,
    feature_names=features,
    class_names=["No Heart Attack", "Heart Attack"],
    filled=True,
    rounded=True,
    fontsize=12,  # Increase font size for clarity
    max_depth=3   # Show only the top 3 levels of the tree
)

# Save the tree as a high-resolution image for better visibility
plt.savefig('decision_tree.png', dpi=300)

# Show the plot
plt.show()

from sklearn.tree import export_text
rules = export_text(dtree, feature_names=features)
print(rules)
# Out:
# |--- BMI <= 15.05
# |   |--- BMI <= 9.55
# |   |   |--- Air_Pollution_Index <= 44.27
# |   |   |   |--- Cholesterol_Level <= 101.15
# |   |   |   |   |--- Region_Heart_Attack_Rate <= 1.51
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Region_Heart_Attack_Rate >  1.51
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- Cholesterol_Level >  101.15
# |   |   |   |   |--- Air_Pollution_Index <= 30.67
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Air_Pollution_Index >  30.67
# |   |   |   |   |   |--- class: 1
# |   |   |--- Air_Pollution_Index >  44.27
# |   |   |   |--- Alcohol_Consumption <= 1.00
# |   |   |   |   |--- Cholesterol_Level <= 124.55
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Cholesterol_Level >  124.55
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- Alcohol_Consumption >  1.00
# |   |   |   |   |--- Region_Heart_Attack_Rate <= 19.39
# |   |   |   |   |   |--- class: 0
# ...
